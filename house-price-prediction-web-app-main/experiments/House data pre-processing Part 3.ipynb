# %%
import pandas as pd
import os

project_folder="C:/Users/hanson/OneDrive/Grad/Grad Project/data_realtorCA/"
output_folder=project_folder+"output"

df=pd.read_csv(output_folder+"/"+"all_after_preprocessing2.csv")

# %%
df.maintenanceManagementCompany.value_counts()
# Out:
# NotListed                                                       5948
# Del Property Management                                          277
# First Service Residential                                        188
# Crossbridge Condominium Services                                 138
# Icon Property Management                                          98
# Icc Property Management                                           88
# Tbd                                                               70
# Maple Ridge Community Management                                  66
# Duka Property Management                                          62
# Crossbridge Condominium Services Ltd.                             40
# Wilson Blanchard                                                  34
# Tba                                                               31
# Crossbridge Property Management                                   31
# Condominium Management Group - 613-237-9519                       30
# ...

# %%
pd.set_option("display.max_rows", 5, "display.max_columns", None) 
#pd.set_option('display.max_colwidth', None) #description full display

# %%
df.head()#
# Out:
#         MLS    price      city           communityName  \
# 0  W5238356   958800  Brampton  Sandringham-Wellington
# 1  W5226917   970000  Brampton       Downtown Brampton
# 2  W5226514  1249900  Brampton  Fletcher's Creek South
# 3  W5234770  1249900  Brampton         Fletcher's West
# 4  W5234047  1249900  Brampton         Fletcher's West
#
#                               address  postal  \
# 0            232 BRUSSELS AVEBrampton  L6Z0G1
# 1  #LOT 12 -57 MCMURCHY AVE SBrampton  L6Y1Y6
# 2          208 ROLLINGWOOD DRBrampton  L6Y5J6
# 3              92 MOFFATT AVEBrampton  L6Y4K8
# 4          85 WHITE TAIL CRESBrampton  L6Y5C1
#
# ...

# %% [markdown]
# ## maintenanceFees

# %%
pd.set_option("display.max_rows", None)
df.maintenanceFees.value_counts()
# Out:
# NotListed                  5682
# $510 (CAD) Monthly           10
# $425 (CAD) Monthly            9
# $450 (CAD) Monthly            9
# $385 (CAD) Monthly            9
# $460 (CAD) Monthly            7
# $395 (CAD) Monthly            7
# $200 (CAD) Monthly            7
# $360 (CAD) Monthly            7
# $417 (CAD) Monthly            7
# $441 (CAD) Monthly            6
# $375 (CAD) Monthly            6
# $285 (CAD) Monthly            6
# $585 (CAD) Monthly            6
# $565 (CAD) Monthly            6
# $650 (CAD) Monthly            6
# $331 (CAD) Monthly            6
# $365 (CAD) Monthly            6
# $500.66 (CAD) Monthly         6
# $595 (CAD) Monthly            5
# $367 (CAD) Monthly            5
# $850 (CAD) Monthly            5
# $430 (CAD) Monthly            5
# $570 (CAD) Monthly            5
# $800 (CAD) Monthly            5
# $300 (CAD) Monthly            5
# $540 (CAD) Monthly            5
# $400 (CAD) Monthly            5
# $322 (CAD) Monthly            5
# ...

# %%
df["maintenanceFees"]=df["maintenanceFees"].str.replace("\(CAD\) Monthly", "")
df["maintenanceFees"]=df["maintenanceFees"].str.replace(",", "")
df["maintenanceFees"]=df["maintenanceFees"].str.replace("$", "")

# %% [markdown]
# ## Assume that if maintenance Fee is not listed, it is 0

# %%
df["maintenanceFees"]=df["maintenanceFees"].str.replace("NotListed", "0")
df["maintenanceFees"]=pd.to_numeric(df["maintenanceFees"], errors='coerce')

# %%
pd.set_option("display.max_rows", None)

# %%
df[df["maintenanceFees"]==0].typeBuilding.value_counts()
# Out:
# C:\Users\hanson\anaconda3\lib\site-packages\IPython\core\displayhook.py:275: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
# House                  4549
# Row / Townhouse         640
# Vacant Land             363
# Duplex                   41
# Apartment                34
# Triplex                  34
# Fourplex                 10
# Other                     5
# Mixed                     2
# Modular                   2
# Manufactured/mobile       2
# Name: typeBuilding, dtype: int64

# %% [markdown]
# remaining columns are:
# maintenanceManagementCompany
# cooling
# heatingType
# exteriorFinish
# buildingFeatures
# amenitiesNearby

# %% [markdown]
# ## maintenanceManagementCompany

# %%
df.maintenanceManagementCompany.value_counts()
# Out:
# NotListed                                                       5948
# Del Property Management                                          277
# First Service Residential                                        188
# Crossbridge Condominium Services                                 138
# Icon Property Management                                          98
# Icc Property Management                                           88
# Tbd                                                               70
# Maple Ridge Community Management                                  66
# Duka Property Management                                          62
# Crossbridge Condominium Services Ltd.                             40
# Wilson Blanchard                                                  34
# Tba                                                               31
# Crossbridge Property Management                                   31
# Condominium Management Group - 613-237-9519                       30
# ...

# %%
#remove phone number
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\d\d\d-\d\d\d-?\d\d\d\d', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\d\d\d-\d\d\d-\s\d\d\d\d', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\d\d\d\s?\d\d\d\s?\d\d\d\d', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\d\d\d\s?\d\d\d-\d\d\d\d', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\d\d\d.\d\d\d.\d\d\d\d', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\d\d\d-\s\d\d\d-\s?\d\d\d\d', '')

df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\(\d\d\d\)\s?\d\d\d-\d\d\d\d', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\(\d\d\d\)\s?\d\d\d-\s?\d\d\d\d', '')

# %%
#df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\d+', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('-', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\(', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\)', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\:', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('.', '')
#df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('[^a-zA-Z\s]', '')

df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace(' Inc', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace(' INC', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace(' Ltd', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace(' Ext', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace(' Ex$', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace(' Ex$', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace(' Telephone', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace(' Tel', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.lower()


df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.strip()

# %% [markdown]
# ## Combine del company

# %%
df[df['maintenanceManagementCompany'].str.contains(r"([Dd]el)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# C:\Users\hanson\anaconda3\lib\site-packages\pandas\core\strings.py:1954: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# array(['del property management', 'dell property management',
#        'delproperty management', 'del property managment',
#        'del property mgmt', 'del property mangement',
#        'cmg angela del giudice x 261', 'club citadel',
#        'del property management,', 'del property management 4163600599',
#        'del property management , concierge',
#        'del property management company', 'del', 'del management company',
#        'del property management onsite',
#        'del property management  howard abbey', 'del management',
#        'del property management  cathie stanish, del,',
#        'del property management 4800 dufferin st', 'del managment',
#        'del prop mgmt', 'del property manangement', 'del property',
# ...

# %%
df.loc[df['maintenanceManagementCompany'].str.contains('^del', na=False), 'maintenanceManagementCompany'] = 'del property management'

# %% [markdown]
# ## Combine Crossbridge company

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(^cross)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['crossbridge condominium services',
#        'crossbridge management services', 'crossbridge condominium',
#        'crossbridge condominiums', 'crossbridge residential',
#        'crossbridge', 'crossbridge  direct , pcc415is@rogerscom',
#        'cross bridge condominium service', 'crossbridge condos',
#        'crossbridge condo services', 'cross bridge condominium services',
#        'crossbridge condominium service', 'crossbridge property mgt',
#        'crossbridge property mgmt /', 'crossbridge condominiums services',
#        'crossbridge condiminium services', 'crossbridge  james mullan',
#        'crossbride condominium services', 'crossbridge condo services #',
#        'crossbridge property management', 'cross bridge condominium',
#        'crossbridge prty mgt, security',
#        'crossbridge condominium services,',
#        'crossbridge condominium services contact',
#        'cross bridge condominiums', 'cross bridge',
# ...

# %%
df.loc[df['maintenanceManagementCompany'].str.contains('crossbridge', na=False), 'maintenanceManagementCompany'] = 'crossbridge condominium services'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(\sbridge)", na=False), 'maintenanceManagementCompany'] = 'crossbridge condominium services'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(^cross)", na=False), 'maintenanceManagementCompany'] = 'crossbridge condominium services'

# %% [markdown]
# ## Combine First Service company

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(service residential)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['first service residential', 'firstservice residential ontario',
#        'frist service residential', 'first service residential ontario',
#        'first service residential property management',
#        'first service residential gail mckee',
#        'first service residential  ontario', 'full service residential',
#        'firstservice residential',
#        'first service residential property mgmt',
#        'first service residential #',
#        'firstservice residential property management',
#        'first service residential 1',
#        'first service residential 4168477261', 'service residential',
#        'first service residential |'], dtype=object)

# %%
df[df['maintenanceManagementCompany']=="first canadian residential"]
# Out:
#            MLS   price     city              communityName  \
# 8155  C5218775  628888  Toronto  Waterfront Communities C1
#
#                           address  postal  \
# 8155  #505 -576 FRONT ST WToronto  M5V0P8
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        description  \
# ...

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(first)", na=False), 'maintenanceManagementCompany'] = 'first service residential'
# Out:
# C:\Users\hanson\anaconda3\lib\site-packages\pandas\core\strings.py:1954: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
df.loc[df['maintenanceManagementCompany']=="frist service residential", 'maintenanceManagementCompany'] = 'first service residential'

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(icondo)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['icondo property management', 'icondo prop mngt',
#        'icondo property'], dtype=object)

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(icc)", na=False), 'maintenanceManagementCompany'] = 'icc property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(icon\s)", na=False), 'maintenanceManagementCompany'] = 'icon property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(icondo\s)", na=False), 'maintenanceManagementCompany'] = 'icondo property management'

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(maple\s?ridge)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['maple ridge property management',
#        'maple ridge community management', 'maple ridge',
#        'maple ridge condo corp', 'maple ridge property',
#        'maple ridge community',
#        'maple ridge comm mgt, fred maggiacomo fmaggiacomo@mrcmcom',
#        'mrcm maple ridge', 'mapleridge property management',
#        'mapleridge community property management',
#        'maple ridge property community',
#        'mapleridge community management',
#        'maple ridge community mangement', 'maple ridge community mgmt',
#        'maple ridge management', 'maple ridge community services,',
#        'maple ridge community property management',
#        'maple ridge management company', 'maple ridge mgmt',
#        'maple ridge community managment', 'maple ridge community manage',
#        'maple ridge community mgt', 'maple ridge condominium management',
#        'maple ridge communitymanagement',
#        'maple ridge management service',
# ...

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(maple\s?ridge)", na=False), 'maintenanceManagementCompany'] = 'maple ridge property management'

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(duka)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['duka property management', 'duka property mangement',
#        'duka management', 'duka property management/',
#        'duka propert management', 'duka', 'duka property management /',
#        'duka property managament',
#        'duka property management 70 temperance street, toronto',
#        'duka prperty management', 'duka property managment'], dtype=object)

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(duka)", na=False), 'maintenanceManagementCompany'] = 'duka property management'

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(tbd)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['tbd'], dtype=object)

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(350)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['350 community'], dtype=object)

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(360)", na=False), 'maintenanceManagementCompany'] = 'threesixty community management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(350)", na=False), 'maintenanceManagementCompany'] = 'threesixty community management'

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(goldview)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['goldview property management',
#        'goldview property management  335', 'goldview property managment',
#        'goldview property management 335',
#        'goldview property management ,', 'goldview property manaement',
#        'goldview management', 'goldview property mgmt',
#        'goldview  property management', 'goldview prop management'],
#       dtype=object)

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(goldview)", na=False), 'maintenanceManagementCompany'] = 'goldview property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(comfort)", na=False), 'maintenanceManagementCompany'] = 'comfort property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(compfort)", na=False), 'maintenanceManagementCompany'] = 'comfort property management'

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(bla)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['wilson, blanchard management', 'wilson blanchard management',
#        'wilson blanchard property management',
#        'wilson blanchard mangement',
#        'wilson & blanchard  nicholas gavey   390', 'wilson blanchard',
#        'wilson blanchart management', 'wilson blanchard  x 452 bahareh',
#        'wilson blanchard pm', 'wilson blanchard property,  ycc397',
#        'wilson blanchard   office', 'wilson blanchand management',
#        'wilson blanchard property',
#        'wilson blanchard property management @',
#        'forest hill residential  blair henderson',
#        'wilson blanchard management 4166422807'], dtype=object)

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(wilson)", na=False), 'maintenanceManagementCompany'] = 'wilson blanchard management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(city\s?s)", na=False), 'maintenanceManagementCompany'] = 'city sites property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(tower)", na=False), 'maintenanceManagementCompany'] = 'citytowers property management'

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(new city)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['new city property mgmt', 'new city property management'],
#       dtype=object)

# %%
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('mgmt', 'management')

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(^condom.*group)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['condominium management group', 'condominium group',
#        'condominium managment group'], dtype=object)

# %%
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('cmg', 'condo management group')

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(^condo\sm)", na=False), 'maintenanceManagementCompany'] = 'condo management group'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(^condom.*group)", na=False), 'maintenanceManagementCompany'] = 'condo management group'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(gpm)", na=False), 'maintenanceManagementCompany'] = 'gpm property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(menre)", na=False), 'maintenanceManagementCompany'] = 'menres property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(apo)", na=False), 'maintenanceManagementCompany'] = 'apollo property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(brook)", na=False), 'maintenanceManagementCompany'] = 'brookfield property'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(elite)", na=False), 'maintenanceManagementCompany'] = 'elite property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(harris)", na=False), 'maintenanceManagementCompany'] = 'nadlanharris property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(tse)", na=False), 'maintenanceManagementCompany'] = 'tse management services'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(grand)", na=False), 'maintenanceManagementCompany'] = 'royale grande property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(^kipl)", na=False), 'maintenanceManagementCompany'] = 'kipling group'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(\skipl)", na=False), 'maintenanceManagementCompany'] = 'forest hill kipling'
df.loc[df['maintenanceManagementCompany'].str.contains(r"(forest)", na=False), 'maintenanceManagementCompany'] = 'forest hill kipling'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(tus)", na=False), 'maintenanceManagementCompany'] = 'meritus group management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(summer)", na=False), 'maintenanceManagementCompany'] = 'summerhill property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(reid)", na=False), 'maintenanceManagementCompany'] = 'reid'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(guild)", na=False), 'maintenanceManagementCompany'] = 'property management guild'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(shiu)", na=False), 'maintenanceManagementCompany'] = 'shiu pong management'
df.loc[df['maintenanceManagementCompany'].str.contains(r"(pong)", na=False), 'maintenanceManagementCompany'] = 'shiu pong management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(self)", na=False), 'maintenanceManagementCompany'] = 'self managed'
df.loc[df['maintenanceManagementCompany'].str.contains(r"(managed)", na=False), 'maintenanceManagementCompany'] = 'self managed'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(ry?lyn)", na=False), 'maintenanceManagementCompany'] = 'larlyn property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(gsa)", na=False), 'maintenanceManagementCompany'] = 'gsa property management'
df.loc[df['maintenanceManagementCompany'].str.contains(r"(gs)", na=False), 'maintenanceManagementCompany'] = 'gsa property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(berk)", na=False), 'maintenanceManagementCompany'] = 'berkley property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(andr)", na=False), 'maintenanceManagementCompany'] = 'andrejs'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(alba)", na=False), 'maintenanceManagementCompany'] = 'alba'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(aa)", na=False), 'maintenanceManagementCompany'] = 'aa property management and associates'
df.loc[df['maintenanceManagementCompany'].str.contains(r"(a\sa)", na=False), 'maintenanceManagementCompany'] = 'aa property management and associates'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(capital\si)", na=False), 'maintenanceManagementCompany'] = 'capital integral'
df.loc[df['maintenanceManagementCompany'].str.contains(r"(integral)", na=False), 'maintenanceManagementCompany'] = 'capital integral'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(medal)", na=False), 'maintenanceManagementCompany'] = 'medallion capital group'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(heart)", na=False), 'maintenanceManagementCompany'] = 'lionheart'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(mance)", na=False), 'maintenanceManagementCompany'] = 'performance property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(shelter)", na=False), 'maintenanceManagementCompany'] = 'shelter canadian'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(eastern)", na=False), 'maintenanceManagementCompany'] = 'eastern ontario property'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(fiest)", na=False), 'maintenanceManagementCompany'] = 'first service residential'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(white\s?hi)", na=False), 'maintenanceManagementCompany'] = 'whitehill residential'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(whitehall)", na=False), 'maintenanceManagementCompany'] = 'whitehall residential'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(york condo)", na=False), 'maintenanceManagementCompany'] = 'york condominium corporation'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(strateg)", na=False), 'maintenanceManagementCompany'] = 'strategic property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(strata)", na=False), 'maintenanceManagementCompany'] = 'strata management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(pro.*house)", na=False), 'maintenanceManagementCompany'] = 'prohouse management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(orion)", na=False), 'maintenanceManagementCompany'] = 'orion'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(malvern)", na=False), 'maintenanceManagementCompany'] = 'malvern'
df.loc[df['maintenanceManagementCompany'].str.contains(r"(mal)", na=False), 'maintenanceManagementCompany'] = 'malvern'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(percel)", na=False), 'maintenanceManagementCompany'] = 'percel'
df.loc[df['maintenanceManagementCompany'].str.contains(r"(cel)", na=False), 'maintenanceManagementCompany'] = 'percel'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(season)", na=False), 'maintenanceManagementCompany'] = 'four seasons hotels and resorts'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(neral)", na=False), 'maintenanceManagementCompany'] = 'general property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(atre)", na=False), 'maintenanceManagementCompany'] = 'atrens management group'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(time)", na=False), 'maintenanceManagementCompany'] = 'times property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(region)", na=False), 'maintenanceManagementCompany'] = 'regional group'

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(luxury)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['luxury canada ulc', 'luxury canada property management'],
#       dtype=object)

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(luxury)", na=False), 'maintenanceManagementCompany'] = 'luxury canada'

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(deer)", na=False)]["maintenanceManagementCompany"].unique()
#deerpark
# Out:
# array(['deerpark management', 'deer park management', 'deerpark'],
#       dtype=object)

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(deer)", na=False), 'maintenanceManagementCompany'] = 'deerpark'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(castle)", na=False), 'maintenanceManagementCompany'] = 'castle condo management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(cape)", na=False), 'maintenanceManagementCompany'] = 'cape'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(duke)", na=False), 'maintenanceManagementCompany'] = 'duke property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(newton)", na=False), 'maintenanceManagementCompany'] = 'newton trelawney'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(nahani)", na=False), 'maintenanceManagementCompany'] = 'nahani'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(sent)", na=False), 'maintenanceManagementCompany'] = 'sentinel'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(provincial)", na=False), 'maintenanceManagementCompany'] = 'provincial property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(kung)", na=False), 'maintenanceManagementCompany'] = 'kung property management'
df.loc[df['maintenanceManagementCompany'].str.contains(r"(tony)", na=False), 'maintenanceManagementCompany'] = 'kung property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(zoran)", na=False), 'maintenanceManagementCompany'] = 'zoran'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(glend)", na=False), 'maintenanceManagementCompany'] = 'glendale'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(dan)", na=False), 'maintenanceManagementCompany'] = 'daniels'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(rab)", na=False), 'maintenanceManagementCompany'] = 'rab'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(dove)", na=False), 'maintenanceManagementCompany'] = 'dove square'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(ace)", na=False), 'maintenanceManagementCompany'] = 'ace condo management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(dms)", na=False), 'maintenanceManagementCompany'] = 'dms'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(crespro)", na=False), 'maintenanceManagementCompany'] = 'crespro'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(mareka)", na=False), 'maintenanceManagementCompany'] = 'mareka'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(marek\s)", na=False), 'maintenanceManagementCompany'] = 'marek'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(best)", na=False), 'maintenanceManagementCompany'] = 'best practices property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(^0)", na=False), 'maintenanceManagementCompany'] = 'notlisted'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(20/20)", na=False), 'maintenanceManagementCompany'] = 'twenty twenty property'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(canlight)", na=False), 'maintenanceManagementCompany'] = 'canlight property'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(george)", na=False), 'maintenanceManagementCompany'] = 'st george'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(gmp)", na=False), 'maintenanceManagementCompany'] = 'gmp property'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(icon$)", na=False), 'maintenanceManagementCompany'] = 'icon property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(horizon prop)", na=False), 'maintenanceManagementCompany'] = 'horizon property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(firest service management)", na=False), 'maintenanceManagementCompany'] = 'first service residential'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(lafon)", na=False), 'maintenanceManagementCompany'] = 'michael lafontaine and associates'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(legacy [&am])", na=False), 'maintenanceManagementCompany'] = 'legacy and associates management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(manor crest)", na=False), 'maintenanceManagementCompany'] = 'manor crest'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(comfield)", na=False), 'maintenanceManagementCompany'] = 'comfield management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(connium)", na=False), 'maintenanceManagementCompany'] = 'connium management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(mrcm)", na=False), 'maintenanceManagementCompany'] = 'mrcm property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(shannex)", na=False), 'maintenanceManagementCompany'] = 'shannex retirement'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(^liv)", na=False), 'maintenanceManagementCompany'] = 'living properties'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(ycc)", na=False), 'maintenanceManagementCompany'] = 'ycc property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(construction)", na=False), 'maintenanceManagementCompany'] = 'None'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(kenair)", na=False), 'maintenanceManagementCompany'] = 'kenair'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(to be determined)", na=False), 'maintenanceManagementCompany'] = 'notlisted'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(enfield)", na=False), 'maintenanceManagementCompany'] = 'enfield'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(occupancy)", na=False), 'maintenanceManagementCompany'] = 'None'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(remington)", na=False), 'maintenanceManagementCompany'] = 'remington facilities'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(astro)", na=False), 'maintenanceManagementCompany'] = 'astro'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(balance)", na=False), 'maintenanceManagementCompany'] = 'balance'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(hendler)", na=False), 'maintenanceManagementCompany'] = 'yl hendler property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(peer)", na=False), 'maintenanceManagementCompany'] = 'peer property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(cove)", na=False), 'maintenanceManagementCompany'] = 'cove management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(tscc)", na=False), 'maintenanceManagementCompany'] = 'tscc'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(peel)", na=False), 'maintenanceManagementCompany'] = 'peel condominium corporation'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(standard)", na=False), 'maintenanceManagementCompany'] = 'ottawa carleton standard condominium corporation'

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(peel)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['peel condominium corporation'], dtype=object)

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(peel)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['peel condominium corporation'], dtype=object)

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(platinum)", na=False), 'maintenanceManagementCompany'] = 'platinum condo'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(^pma)", na=False), 'maintenanceManagementCompany'] = 'pma realty'

# %%
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('&', 'and')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\'', '')
#df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('[^a-zA-Z\s]', '')

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(aykler)", na=False), 'maintenanceManagementCompany'] = 'aykler real estate'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(not assigned)", na=False), 'maintenanceManagementCompany'] = 'notlisted'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(cold)", na=False), 'maintenanceManagementCompany'] = 'coldwell banker realty'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(wycliffe)", na=False), 'maintenanceManagementCompany'] = 'wycliffe marlee limited'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(affable)", na=False), 'maintenanceManagementCompany'] = 'affable property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(^carleton)", na=False), 'maintenanceManagementCompany'] = 'carleton condo corp'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(ottawa)", na=False), 'maintenanceManagementCompany'] = 'ottawa carleton standard condominium corporation'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(vista)", na=False), 'maintenanceManagementCompany'] = 'vista property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(stronghold)", na=False), 'maintenanceManagementCompany'] = 'stronghold management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(east\s?way)", na=False), 'maintenanceManagementCompany'] = 'eastway manangement'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(ritz)", na=False), 'maintenanceManagementCompany'] = 'ritz carlton property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(cpo)", na=False), 'maintenanceManagementCompany'] = 'canadian properties operator management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(complet)", na=False), 'maintenanceManagementCompany'] = 'complete condo management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(premiere)", na=False), 'maintenanceManagementCompany'] = 'ppma'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(principle)", na=False), 'maintenanceManagementCompany'] = 'principle property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(ikon)", na=False), 'maintenanceManagementCompany'] = 'icon property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(arthrex)", na=False), 'maintenanceManagementCompany'] = 'arthex property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(j t b)", na=False), 'maintenanceManagementCompany'] = 'jtb group'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(jtb)", na=False), 'maintenanceManagementCompany'] = 'jtb group'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(jandw)", na=False), 'maintenanceManagementCompany'] = 'j and w condo management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(^na$)", na=False), 'maintenanceManagementCompany'] = 'notlisted'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(n//a)", na=False), 'maintenanceManagementCompany'] = 'notlisted'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(menkes)", na=False), 'maintenanceManagementCompany'] = 'menkes property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(non)", na=False), 'maintenanceManagementCompany'] = 'notlisted'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(wentworth)", na=False), 'maintenanceManagementCompany'] = 'wentworth'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(guile)", na=False), 'maintenanceManagementCompany'] = 'property management guild'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(appolo)", na=False), 'maintenanceManagementCompany'] = 'appollo'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(kindle)", na=False), 'maintenanceManagementCompany'] = 'kindle property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(g p m)", na=False), 'maintenanceManagementCompany'] = 'gpm property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(shabri)", na=False), 'maintenanceManagementCompany'] = 'shabri property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(not decided yet)", na=False), 'maintenanceManagementCompany'] = 'notlisted'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(pcc)", na=False), 'maintenanceManagementCompany'] = 'peel condominium corporation'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(st john)", na=False), 'maintenanceManagementCompany'] = 'st john mcnicolle center'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(pscc)", na=False), 'maintenanceManagementCompany'] = 'pscc'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(t s e)", na=False), 'maintenanceManagementCompany'] = 'tse management services'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(artex)", na=False), 'maintenanceManagementCompany'] = 'arthex property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(synapse)", na=False), 'maintenanceManagementCompany'] = 'synapse property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(ppg)", na=False), 'maintenanceManagementCompany'] = 'ppg management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(metropolis)", na=False), 'maintenanceManagementCompany'] = 'metropolis management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(harmony)", na=False), 'maintenanceManagementCompany'] = 'harmony management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(^i condo)", na=False), 'maintenanceManagementCompany'] = 'icondo property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(peei)", na=False), 'maintenanceManagementCompany'] = 'peel condominium corporation'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(mertius)", na=False), 'maintenanceManagementCompany'] = 'meritus group management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(mertis)", na=False), 'maintenanceManagementCompany'] = 'meritus group management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(jandw)", na=False), 'maintenanceManagementCompany'] = 'j and w condo management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(kippling)", na=False), 'maintenanceManagementCompany'] = 'kipling group'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(ican)", na=False), 'maintenanceManagementCompany'] = 'icon property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(key)", na=False), 'maintenanceManagementCompany'] = 'key property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(lexington)", na=False), 'maintenanceManagementCompany'] = 'lexington property management'

# %%
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\@', '')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('\'', '')

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(lariyn)", na=False), 'maintenanceManagementCompany'] = 'larlyn property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(^cie)", na=False), 'maintenanceManagementCompany'] = 'cie property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(orian)", na=False), 'maintenanceManagementCompany'] = 'orion'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(laperriere)", na=False), 'maintenanceManagementCompany'] = 'laperriere collision'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(simson)", na=False), 'maintenanceManagementCompany'] = 'simsons management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(crespo)", na=False), 'maintenanceManagementCompany'] = 'crespro'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(prescision)", na=False), 'maintenanceManagementCompany'] = 'precision management services'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(percision)", na=False), 'maintenanceManagementCompany'] = 'precision management services'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(uptown)", na=False), 'maintenanceManagementCompany'] = 'uptown residences'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(middle)", na=False), 'maintenanceManagementCompany'] = 'middlefield property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(condogroupca)", na=False), 'maintenanceManagementCompany'] = 'condo management group'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(landh)", na=False), 'maintenanceManagementCompany'] = 'l and h property management'

# %%
df.loc[df['maintenanceManagementCompany'].str.contains(r"(solution)", na=False), 'maintenanceManagementCompany'] = 'condo solutions management'

# %%
df[df['maintenanceManagementCompany'].str.contains(r"(solution)", na=False)]["maintenanceManagementCompany"].unique()
# Out:
# array(['condo solutions management'], dtype=object)

# %%
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.strip()
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace(r'^$', 'notlisted')
df['maintenanceManagementCompany'] = df['maintenanceManagementCompany'].str.replace('None', 'notlisted')

# %% [markdown]
# ## Output Data, and then go to Part 4 code

# %%
df.to_csv(output_folder+"/"+"all_after_preprocessing3.csv", index=False)
